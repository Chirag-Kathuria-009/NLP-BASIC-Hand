# %%
# !pip install jieba

# %%
import jieba
seg = jieba.cut('把句子中所有的可以成词的词语都扫描出来',cut_all = True)
print(" ".join(seg))
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache /tmp/jieba.cache
# Loading model cost 0.787 seconds.
# Prefix dict has been built successfully.
# 把 句子 中所 所有 的 可以 成 词 的 词语 都 扫描 描出 描出来 出来

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
import nltk
text = "Children’s day is commemorated with great joy in our nation. On this special day Pt. Jawaharlal Nehru is given tribute. The folios of the life of Pt. Nehru are turned on this day and the offering arranged by him for the betterment of the kids is told."

for txt in text:
  sentence = nltk.sent_tokenize(text)
print(sentence)
# Out:
# ['Children’s day is commemorated with great joy in our nation.', 'On this special day Pt.', 'Jawaharlal Nehru is given tribute.', 'The folios of the life of Pt.', 'Nehru are turned on this day and the offering arranged by him for the betterment of the kids is told.']

# %%
for txt in text:
  sentences = nltk.sent_tokenize(text)
  for sentence in sentences:
    words = nltk.word_tokenize(sentence)
    print(words)
# Out:
# ['Children', '’', 's', 'day', 'is', 'commemorated', 'with', 'great', 'joy', 'in', 'our', 'nation', '.']
# ['On', 'this', 'special', 'day', 'Pt', '.']
# ['Jawaharlal', 'Nehru', 'is', 'given', 'tribute', '.']
# ['The', 'folios', 'of', 'the', 'life', 'of', 'Pt', '.']
# ['Nehru', 'are', 'turned', 'on', 'this', 'day', 'and', 'the', 'offering', 'arranged', 'by', 'him', 'for', 'the', 'betterment', 'of', 'the', 'kids', 'is', 'told', '.']
# ['Children', '’', 's', 'day', 'is', 'commemorated', 'with', 'great', 'joy', 'in', 'our', 'nation', '.']
# ['On', 'this', 'special', 'day', 'Pt', '.']
# ['Jawaharlal', 'Nehru', 'is', 'given', 'tribute', '.']
# ['The', 'folios', 'of', 'the', 'life', 'of', 'Pt', '.']
# ['Nehru', 'are', 'turned', 'on', 'this', 'day', 'and', 'the', 'offering', 'arranged', 'by', 'him', 'for', 'the', 'betterment', 'of', 'the', 'kids', 'is', 'told', '.']
# ['Children', '’', 's', 'day', 'is', 'commemorated', 'with', 'great', 'joy', 'in', 'our', 'nation', '.']
# ...

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
for txt in text:
  sentences = nltk.sent_tokenize(text)
  for sentence in sentences:
    words = nltk.word_tokenize(sentence)
    tag_word = nltk.pos_tag(words)
    print(tag_word)
# Out:
# [('Children', 'NNP'), ('’', 'NNP'), ('s', 'NN'), ('day', 'NN'), ('is', 'VBZ'), ('commemorated', 'VBN'), ('with', 'IN'), ('great', 'JJ'), ('joy', 'NN'), ('in', 'IN'), ('our', 'PRP$'), ('nation', 'NN'), ('.', '.')]
# [('On', 'IN'), ('this', 'DT'), ('special', 'JJ'), ('day', 'NN'), ('Pt', 'NNP'), ('.', '.')]
# [('Jawaharlal', 'NNP'), ('Nehru', 'NNP'), ('is', 'VBZ'), ('given', 'VBN'), ('tribute', 'NN'), ('.', '.')]
# [('The', 'DT'), ('folios', 'NNS'), ('of', 'IN'), ('the', 'DT'), ('life', 'NN'), ('of', 'IN'), ('Pt', 'NNP'), ('.', '.')]
# [('Nehru', 'NN'), ('are', 'VBP'), ('turned', 'VBN'), ('on', 'IN'), ('this', 'DT'), ('day', 'NN'), ('and', 'CC'), ('the', 'DT'), ('offering', 'NN'), ('arranged', 'VBN'), ('by', 'IN'), ('him', 'PRP'), ('for', 'IN'), ('the', 'DT'), ('betterment', 'NN'), ('of', 'IN'), ('the', 'DT'), ('kids', 'NNS'), ('is', 'VBZ'), ('told', 'VBN'), ('.', '.')]
# ...

# %%
from nltk.tokenize import TweetTokenizer
text = 'Today is Harry Potter birthday'
tknizer = TweetTokenizer()
tknizer.tokenize(text)
# Out:
# ['Today', 'is', 'Harry', 'Potter', 'birthday']

# %%
from urllib import request
url = "http://www.gutenberg.org/files/2554/2554-0.txt"
response = request.urlopen(url)
raw = response.read().decode('utf8')

type(raw)
print(raw[0:60])
tokens = nltk.word_tokenize(raw)
type(tokens)
# Out:
# ﻿The Project Gutenberg EBook of Crime and Punishment, by Fyo
# list
